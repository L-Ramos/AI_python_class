# %% [markdown]
# #Your own Project
#
# ###Now it is time for you to work on a project of your own.
# ###Get your own data or the one from this [ link: ](https://www.kaggle.com/c/titanic) or this [link](https://www.kaggle.com/uciml/pima-indians-diabetes-database).
#
# So far we've seen:
#
# * What are the important python libraries (Numpy, Pandas, Sklearn...)
# * How to visualize and clean your data (scatter-plot, corerlation matrix)
# * How to select the most important features (SelectKbest)
# * How to create a model to predict your label
# * How to optimize your models (Gridsearch)
# * How to do all that avoiding over-optimistic results (using cross-validation)
#
# Below we'll describe the step-by-step fo what we'd expect to see in your pipeline.
#
# 1 - Figure out what your research question is and if you can answer it with your data.
#
# 2 - Visualize and clean your data: Check for missing values, correlations, outliers and how to handle those (imputation?)
#
# 2.1 - Check your labels, are they unbalanced? How are you going to deal with that?
#
# 3 - Start your pipeline, you can include Feature Selection/Engineering, select and optimize the classifiers you want to use and choose which metrics you'll use for evaluation (keep class balance in mind).
#
# 4 - Report the results over several cross-validation iterations, remember to save all of them so you can compute SD or CI later.
#
# 5 - Explore different approaches, different (or no) feature selection method, different classifiers or maybe even a different label.
#
# 6 - Organize your results, plot graphs with the important features if thats relevant for your research question, compare the results from the different classifiers, make your results easier to interpret.

# %%
import pandas as pd

file=pd.read_csv("E:/test.csv",sep=';')

# %%
#Start your Project!
